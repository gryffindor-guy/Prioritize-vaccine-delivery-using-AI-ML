# %% [markdown]
# <a href="https://colab.research.google.com/github/gryffindor-guy/Prioritize-vaccine-delivery-using-AI-ML/blob/main/Prioritize_vaccine_delivery_using_AI_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data  = pd.read_csv('state_level_daily.csv')
data.head()
# Out:
#    Unnamed: 0       Date  ... Recovered                   State_Name
# 0           0  01-Apr-20  ...         0  Andaman and Nicobar Islands
# 1           1  01-Apr-20  ...         1               Andhra Pradesh
# 2           2  01-Apr-20  ...         0            Arunachal Pradesh
# 3           3  01-Apr-20  ...         0                        Assam
# 4           4  01-Apr-20  ...         0                        Bihar
#
# [5 rows x 7 columns]

# %%
data.shape
# Out:
# (5694, 7)

# %%
data.isna().any()
# Out:
# Unnamed: 0    False
# Date          False
# State         False
# Confirmed     False
# Deceased      False
# Recovered     False
# State_Name    False
# dtype: bool

# %%
del data['Unnamed: 0']

# %%
data.shape
# Out:
# (5694, 6)

# %%
sns.pairplot(data)

# %% [markdown]
# 1.We have gathered different datasets.
#
# 2.we have started feature engineering and dimensionality reduction.
#
# 3.We will soon upload the datasets after feature engineering.
